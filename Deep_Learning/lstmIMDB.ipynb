# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, GRU
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
(X_train, y_train),(X_test, y_test) = imdb.load_data(num_words=10000)

# %%
print(X_train.shape)
# Out:
# (25000,)

# %%
print(y_train.shape)
# Out:
# (25000,)

# %%
print(X_train[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
X_train = pad_sequences(X_train,maxlen=200)

# %%
X_test = pad_sequences(X_test,maxlen=200)

# %%
model = Sequential([
    Embedding(input_dim=10000,output_dim=64, input_length=200),
    LSTM(64),
    Dense(1,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=5,batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 45ms/step - accuracy: 0.7801 - loss: 0.4550 - val_accuracy: 0.8586 - val_loss: 0.3452
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.8921 - loss: 0.2723 - val_accuracy: 0.8542 - val_loss: 0.3559
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 0.9232 - loss: 0.2057 - val_accuracy: 0.8588 - val_loss: 0.3301
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 0.9421 - loss: 0.1516 - val_accuracy: 0.8662 - val_loss: 0.3700
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 0.9568 - loss: 0.1217 - val_accuracy: 0.8686 - val_loss: 0.4282

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Loss : ",loss)
print("Accuracy : ",accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8592 - loss: 0.4600
# Loss :  0.46001940965652466
# Accuracy :  0.8592399954795837

# %%
model = Sequential([
    Embedding(input_dim=10000,output_dim=24, input_length=200),
    GRU(64),
    Dense(1,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=5,batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 45ms/step - accuracy: 0.7426 - loss: 0.4879 - val_accuracy: 0.8446 - val_loss: 0.4034
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.8912 - loss: 0.2708 - val_accuracy: 0.8712 - val_loss: 0.3142
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 0.9236 - loss: 0.1995 - val_accuracy: 0.8730 - val_loss: 0.3229
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 0.9467 - loss: 0.1499 - val_accuracy: 0.8572 - val_loss: 0.3422
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 0.9581 - loss: 0.1227 - val_accuracy: 0.8622 - val_loss: 0.3830

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Loss : ",loss)
print("Accuracy : ",accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8568 - loss: 0.4004
# Loss :  0.40039557218551636
# Accuracy :  0.8568000197410583
